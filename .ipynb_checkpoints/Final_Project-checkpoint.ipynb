# %%
# Figure 3G

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
#load data from xls file and transfer it into a dataframe
Data_1 = pd.ExcelFile('Paper1_figure_3G.xls')

# %%
df = Data_1.parse('Sheet1', skiprows=2, index_col=None)

# %%
print(df)
# Out:
#     IgG2b  anti-CD4  anti-CD8
# 0  12.334    11.063     4.859
# 1  10.017    11.238     5.842
# 2  10.054    11.598     6.592
# 3   7.440    11.355     6.613
# 4  10.090    11.986       NaN
# 5   9.682    11.210       NaN
# 6  10.049       NaN       NaN

# %%
print(df.values)
# Out:
# [[12.334 11.063  4.859]
#  [10.017 11.238  5.842]
#  [10.054 11.598  6.592]
#  [ 7.44  11.355  6.613]
#  [10.09  11.986    nan]
#  [ 9.682 11.21     nan]
#  [10.049    nan    nan]]

# %%
colors = 'brg'

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator

# %%
group11 = []
group12 = []
group13 = []

# %%
#load data from xls file and transfer it into a dataframe
Data_1 = pd.ExcelFile('Paper1_figure_3G.xls')
df1 = Data_1.parse('Sheet1', skiprows=2, index_col=None)

#replace the empty cell with 0 in the data sheet
df1.fillna(0,inplace=True)
group11 = []
group12 = []
group13 = []

for ii in range(len(df1.values)):
    #skip data whose value equals 0
    if df1.values[ii][0] != 0:
        group11.append(df1.values[ii][0])
    if df1.values[ii][1] != 0:
        group12.append(df1.values[ii][1])
    if df1.values[ii][2] != 0:
        group13.append(df1.values[ii][2])

print(group11)
print(group12)

#Perform Mann–Whitney Test
u_statistic_11, pVal_11 = stats.mannwhitneyu(group11, group12, alternative = 'two-sided')
print(u_statistic_11, pVal_11)
u_statistic_12, pVal_12 = stats.mannwhitneyu(group11, group13, alternative = 'two-sided')
print(u_statistic_12, pVal_12)
# Out:
# [12.334, 10.017, 10.054, 7.44, 10.09, 9.682, 10.049]
# [11.063, 11.238, 11.598, 11.355, 11.986, 11.21]
# 6.0 0.03496503496503496
# 28.0 0.006060606060606061

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

# %%
infile = 'Modified_3G.xls'

# load data from files
df = pd.read_excel(infile, sheet_name=0, decimal='.', skipfooter=0)
df_unit = df.groupby('Treatment').mean().reset_index()

# sort values
df_unit = df_unit.sort_values('Score', ascending=False)
order = df_unit['Treatment']

#plot boxplot
g = sns.catplot(data=df, x="Treatment", y="Score", kind="box")
sns.swarmplot(data=df, x="Treatment", y="Score", color="k", size=10, ax=g.ax).set(title = "Figure 3G(a): Quantification expression \n  Mann-Whitney U test")
g.ax.set(xlabel='',ylabel='gMFI*1000')

plt.savefig('Figure_3G(a)')

# %%
#load data from xls file and transfer it into a dataframe
Data_1 = pd.ExcelFile('Paper1_figure_3G.xls')
df2 = Data_1.parse('Sheet2', skiprows=2, index_col=None)

#replace the empty cell with 0 in the data sheet
df2.fillna(0,inplace=True)
group21 = []
group22 = []
group23 = []
    
for ii in range(len(df2.values)):
    if df2.values[ii][0] != 0:
        group21.append(df2.values[ii][0])
    if df2.values[ii][1] != 0:
        group22.append(df2.values[ii][1])
    if df2.values[ii][2] != 0:
        group23.append(df2.values[ii][2])

print(group22)
print(group23)

#Perform Mann–Whitney Test
u_statistic_21, pVal_21 = stats.mannwhitneyu(group21, group22, alternative = 'two-sided')
print(u_statistic_21, pVal_21)
u_statistic_22, pVal_22 = stats.mannwhitneyu(group21, group23, alternative = 'two-sided')
print(u_statistic_22, pVal_22)
# Out:
# [2.616, 2.962, 2.859, 2.536, 2.541, 3.139]
# [5.39, 3.762, 5.96, 4.905]
# 26.0 0.5337995337995338
# 3.0 0.04242424242424242

# %%
infile = 'Modified_3G.xls'

# load data from files
df = pd.read_excel(infile, sheet_name=2, decimal='.', skipfooter=0)
df_unit = df.groupby('Treatment').mean().reset_index()

df_unit = df_unit.sort_values('Score', ascending=False)
order = df_unit['Treatment']

#plot boxplot
g = sns.catplot(data=df, x="Treatment", y="Score", kind="box")
#sns.boxplot(data=df, x="Treatment", y="Score")
sns.swarmplot(data=df, x="Treatment", y="Score", color="k", size=10, ax=g.ax).set(title = "Figure 3G(b): Quantification expression \n Mann-Whitney U test")
g.ax.set(xlabel='',ylabel='gMFI*1000')

plt.savefig('Figure_3G(b)')

# %%
import numpy

# %%
#load data from xls file and transfer it into a dataframe
Data_1 = pd.ExcelFile('Paper1_figure_3G.xls')
df3 = Data_1.parse('Sheet3', skiprows=2, index_col=None)

#replace the empty cell with 0 in the data sheet
df3.fillna(0,inplace=True)

group31 = []
group32 = []
group33 = []
    
for ii in range(len(df3.values)):
    if df3.values[ii][0] != 0:
        group31.append(df3.values[ii][0])
    if df3.values[ii][1] != 0:
        group32.append(df3.values[ii][1])
    if df3.values[ii][2] != 0:
        group33.append(df3.values[ii][2])

#Perform Mann–Whitney Test
u_statistic_31, pVal_31 = stats.mannwhitneyu(group31, group32, alternative = 'two-sided')
print(u_statistic_31, pVal_31)
u_statistic_32, pVal_32 = stats.mannwhitneyu(group31, group33, alternative = 'two-sided')
print(u_statistic_32,pVal_32)
# Out:
# 26.0 0.5337995337995338
# 28.0 0.006060606060606061

# %%
infile = 'Modified_3G.xls'

# load data from files
df = pd.read_excel(infile, sheet_name=3, decimal='.', skipfooter=0)
df_unit = df.groupby('Treatment').mean().reset_index()

# sort values
df_unit = df_unit.sort_values('Score', ascending=False)
order = df_unit['Treatment']

g = sns.catplot(data=df, x="Treatment", y="Score", kind="box")
sns.swarmplot(data=df, x="Treatment", y="Score", color="k", size=10, ax=g.ax).set(title = "Figure 3G(c): Quantification expression \n Mann-Whitney U test")
g.ax.set(xlabel='',ylabel='gMFI*1000')

plt.savefig('Figure_3G(c)')

# %%
#load data from xls file and transfer it into a dataframe
Data_1 = pd.ExcelFile('Paper1_figure_3G.xls')
df4 = Data_1.parse('Sheet4', skiprows=2, index_col=None)

#replace the empty cell with 0 in the data sheet
df4.fillna(0,inplace=True)

group41 = []
group42 = []
group43 = []
    
for ii in range(len(df4.values)):
    if df4.values[ii][0] != 0:
        group41.append(df4.values[ii][0])
    if df4.values[ii][1] != 0:
        group42.append(df4.values[ii][1])
    if df4.values[ii][2] != 0:
        group43.append(df4.values[ii][2])

#Perform Mann–Whitney Test
u_statistic_41, pVal_41 = stats.mannwhitneyu(group41, group42, alternative = 'two-sided')
print(u_statistic_41, pVal_41)
u_statistic_42, pVal_42 = stats.mannwhitneyu(group41, group43, alternative = 'two-sided')
print(u_statistic_42, pVal_42)
# Out:
# 15.0 0.4452214452214452
# 26.0 0.024242424242424242

# %%
infile = 'Modified_3G.xls'

# load data from files
df = pd.read_excel(infile, sheet_name=1, decimal='.', skipfooter=0)
df_unit = df.groupby('Treatment').mean().reset_index()

# sort values
df_unit = df_unit.sort_values('Score', ascending=False)
order = df_unit['Treatment']

g = sns.catplot(data=df, x="Treatment", y="Score", kind="box")
sns.swarmplot(data=df, x="Treatment", y="Score", color="k", size=10, ax=g.ax).set(title = "Figure 3G(d): Quantification expression \n Mann-Whitney U test")
g.ax.set(xlabel='',ylabel='gMFI*1000')

plt.savefig('Figure_3G(d)')

# %%
# Figure 5A

# %%
infile = 'Modified_5A.xls'

#load data from files
df1 = pd.read_excel(infile, sheet_name=2, names = ['Treatment', 'Score'], decimal='.', skipfooter=0)
df1_unit = df1.groupby('Treatment').mean().reset_index()

# sort 
df1_unit = df1_unit.sort_values('Score', ascending=False)
order = df1_unit['Treatment']
g = sns.catplot(data=df1, x="Treatment", y="Score", kind="box")

#set the range of x values
xlim = -0.5, 5
plt.hlines(1, linestyles='dashed', color="k", *xlim)
sns.swarmplot(data=df1, x="Treatment", y="Score", color="k", size=5, ax=g.ax).set(title = "Figure 5A(a). Flow cytometric analysis \n Test used: One-way ANOVA")

#rotate the x labels
g.set_xticklabels(rotation=45)

# set y labels
g.ax.set(xlabel='',ylabel='Fold induction')

plt.savefig('Figure_5A(a)')

# %%
infile = 'Modified_5A.xls'

#load data from files
df2 = pd.read_excel(infile, sheet_name=0, names = ['Treatment', 'Score'], decimal='.', skipfooter=0)
df2_unit = df2.groupby('Treatment').mean().reset_index()

# sort 
df2_unit = df2_unit.sort_values('Score', ascending=False)
order = df2_unit['Treatment']
g = sns.catplot(data=df2, x="Treatment", y="Score", kind="box")

#set the range of x values
xlim = -0.5, 5
plt.hlines(1, linestyles='dashed', color="k", *xlim)
sns.swarmplot(data=df2, x="Treatment", y="Score", color="k", size=5, ax=g.ax).set(title = "Figure 5A(b). Flow cytometric analysis \n Test used: One-way ANOVA")

#rotate the x labels
g.set_xticklabels(rotation=45)

# set y labels
g.ax.set(xlabel='',ylabel='Fold induction')

plt.savefig('Figure_5A(b)')

# %%
infile = 'Modified_5A.xls'

df3 = pd.read_excel(infile, sheet_name=1, names = ['Treatment', 'Score'], decimal='.', skipfooter=0)
df3_unit = df.groupby('Treatment').mean().reset_index()

# sort prod units by avg score
df3_unit = df3_unit.sort_values('Score', ascending=False)
order = df3_unit['Treatment']
g = sns.catplot(data=df3, x="Treatment", y="Score", kind="box")

xlim = -0.5, 5
plt.hlines(1, linestyles='dashed', color="k", *xlim)
sns.swarmplot(data=df3, x="Treatment", y="Score", color="k", size=5, ax=g.ax).set(title = "Figure 5A(c). Flow cytometric analysis \n Test used: One-way ANOVA")

#rotate the x labels
g.set_xticklabels(rotation=45)

# set y labels
g.ax.set(xlabel='',ylabel='Fold induction')

plt.savefig('Figure_5A(c)')

# %%
infile = 'Modified_5A.xls'

df4 = pd.read_excel(infile, sheet_name=3, names = ['Treatment', 'Score'], decimal='.', skipfooter=0)
df4_unit = df4.groupby('Treatment').mean().reset_index()

# sort prod units by avg score
df4_unit = df4_unit.sort_values('Score', ascending=False)
order = df4_unit['Treatment']
g = sns.catplot(data=df4, x="Treatment", y="Score", kind="box")

xlim = -0.5, 5
plt.hlines(1, linestyles='dashed', color="k", *xlim)
sns.swarmplot(data=df4, x="Treatment", y="Score", color="k", size=5, ax=g.ax).set(title = "Figure 5A(d). Flow cytometric analysis \n Test used: One-way ANOVA")

# set y labels
g.ax.set(xlabel='',ylabel='Fold induction')

plt.savefig('Figure_5A(d)')

# %%
#Figure 5C: Grouped bar chart with labels

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#load data from xls file and transfer it into a dataframe
Data_3 = pd.ExcelFile('Paper1_figure_5C.xls')

# %%
df = Data_3.parse('Sheet1', skiprows=2, na_values=['NA'])

# %%
print(df)
# Out:
#   Unnamed: 0  21% O2  Unnamed: 2  Unnamed: 3  Unnamed: 4  1.5% O2  Unnamed: 6  \
# 0       BMDC    0.14        0.16        0.20        0.31     5.42        0.30
# 1   BMDC+SL8    5.16        4.89        5.48        7.94    33.90       36.10
# 2        TAM    0.61        0.65        5.60        1.10     1.86        1.82
# 3     2x TAM    1.23        1.14        1.49         NaN     8.08        9.66
# 4        TAM    0.22        1.33        0.31        0.26     0.20        0.24
# 5     2x TAM    0.23        0.19        0.21        0.19     0.26        0.24
#
#    Unnamed: 7  Unnamed: 8
# 0        0.25        0.18
# 1       35.80       36.50
# 2        3.95        3.25
# 3        4.03         NaN
# 4        0.20        0.17
# 5        2.14        0.78

# %%
df.fillna(0,inplace=True)
print(df)
# Out:
#   Unnamed: 0  21% O2  Unnamed: 2  Unnamed: 3  Unnamed: 4  1.5% O2  Unnamed: 6  \
# 0       BMDC    0.14        0.16        0.20        0.31     5.42        0.30
# 1   BMDC+SL8    5.16        4.89        5.48        7.94    33.90       36.10
# 2        TAM    0.61        0.65        5.60        1.10     1.86        1.82
# 3     2x TAM    1.23        1.14        1.49        0.00     8.08        9.66
# 4        TAM    0.22        1.33        0.31        0.26     0.20        0.24
# 5     2x TAM    0.23        0.19        0.21        0.19     0.26        0.24
#
#    Unnamed: 7  Unnamed: 8
# 0        0.25        0.18
# 1       35.80       36.50
# 2        3.95        3.25
# 3        4.03        0.00
# 4        0.20        0.17
# 5        2.14        0.78

# %%
group_labels = []

# %%
for i in range(len(df.values)):
    group_labels.append(df.values[i][0])

# %%
print(group_labels)
# Out:
# ['BMDC', 'BMDC+SL8', 'TAM', '2x TAM', 'TAM', '2x TAM']

# %%
group_21 = []
group_15 = []
group_21_v = []
group_15_v = []
group_significance = []

# %%
for i in range(len(df.values)):
    group_temp1 = []
    group_temp2 = []
    
    for ii in range(1,5):
        if df.values[i][ii] != 0 :
            group_temp1.append(df.values[i][ii])
            
    for ii in range(5,9):
        if df.values[i][ii] != 0:
            group_temp2.append(df.values[i][ii])
    
    t_statistic, pVal = stats.ttest_ind(group_temp1, group_temp2)
    group_significance.append(pVal)
    
    group_21.append(np.mean(group_temp1))
    group_15.append(np.mean(group_temp2))
    
    group_21_v.append(stats.sem(group_temp1))
    group_15_v.append(stats.sem(group_temp2))

# %%
print(group_significance)
# Out:
# [0.3423301108598144, 5.415611882226838e-08, 0.5998745768828773, 0.023715564512578263, 0.26702588434159985, 0.19553173042083002]

# %%
from matplotlib.markers import TICKDOWN

def significance_bar(start,end,height,displaystring,linewidth = 1.2,markersize = 8,boxpad  =0.3,fontsize = 15,color = 'k'):
    # draw a line with downticks at the ends
    plt.plot([start,end],[height]*2,'-',color = color,lw=linewidth,marker = TICKDOWN,markeredgewidth=linewidth,markersize = markersize)
    # draw the text with a bounding box covering up the line
    plt.text(0.5*(start+end),height,displaystring,ha = 'center',va='center',bbox=dict(facecolor='1.', edgecolor='none',boxstyle='Square,pad='+str(boxpad)),size = fontsize)

# %%
import numpy as np
import matplotlib.pyplot as plt

# the label locations
x = np.arange(len(group_labels))
# the width of the bars
width = 0.35 

# If we were to simply plot pts, we'd lose most of the interesting
# details due to the outliers. So let's 'break' or 'cut-out' the y-axis
# into two portions - use the top (ax1) for the outliers, and the bottom
# (ax2) for the details of the majority of our data
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True,gridspec_kw={'height_ratios':[1,5]})
fig.subplots_adjust(hspace=0.15)  # adjust space between axes

# plot the same data on both axes
rects1 = ax1.bar(x - width/2, group_21, width, label='21%$O_{2}$', color = 'k')
rects2 = ax1.bar(x + width/2, group_15, width, label='1.5%$O_{2}$',color = 'r')
rects1 = ax2.bar(x - width/2, group_21, width, color = 'k')
rects2 = ax2.bar(x + width/2, group_15, width, color = 'r')

# Add error bars for different groups of data
for pos, y, err in zip(x - width/2, group_21, group_21_v):
    ax1.errorbar(pos, y, err, lw = 1,
                capsize = 4, capthick = 2,
                color = "black")

for pos, y, err in zip(x + width/2, group_15, group_15_v):
    ax1.errorbar(pos, y, err, lw = 1,
                capsize = 4, capthick = 2,
                color = "red")
for pos, y, err in zip(x - width/2, group_21, group_21_v):
    ax2.errorbar(pos, y, err, lw = 1,
                capsize = 4, capthick = 2,
                color = "black")

for pos, y, err in zip(x + width/2, group_15, group_15_v):
    ax2.errorbar(pos, y, err, lw = 1,
                capsize = 4, capthick = 2,
                color = "red")

# zoom-in / limit the view to different portions of the data
ax1.set_ylim(30, 50)  # outliers only
ax2.set_ylim(0, 10)  # most of the data
gridspec_kw={'height_ratios': [1,2]}

# hide the spines between ax1 and ax2
ax1.spines.bottom.set_visible(False)
ax2.spines.top.set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)  
ax2.xaxis.tick_bottom()

# Only show ticks on the left and bottom spines
ax1.yaxis.set_ticks_position('left')
 
# turn towards the cut-out slanted lines.
# We create line objects in axes coordinates, in which (0,0), (0,1),
# (1,0), and (1,1) are the four corners of the axes.
# The slanted lines themselves are markers at those locations, such that the
# lines keep their angle and position, independent of the axes size or scale
# Finally, we need to disable clipping.

d = .5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)
    
ax2.set_ylabel('%PD-1$^+$ of total CDB$^+$')
ax2.set_xticks(x, group_labels, rotation = 45)
ax1.legend(loc='upper right',frameon=False)

# add footnode of p values of different groups performen by un-paired t test
plt.text(-1,-4,"Significance of first group is %.2f." % group_significance[0])
plt.text(-1,-4.7,"Significance of second group is %.2f." % group_significance[1])
plt.text(-1,-5.3,"Significance of third group is %.2f." % group_significance[2])
plt.text(-1,-6.0,"Significance of fourth group is %.2f." % group_significance[3])
plt.text(-1,-6.7,"Significance of fifth group is %.2f." % group_significance[4])
plt.text(-1,-7.3,"Significance of last group is %.2f." % group_significance[5])

# set a foot node 
ax1.set_title('Figure5C.quantification on activated CD8+ OT-I T cells \n tests used: t test')

plt.savefig("Figure_5C")
